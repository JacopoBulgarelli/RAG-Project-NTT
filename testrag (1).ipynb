# %% [markdown]
# ### Requirements

# %%
# %pip install transformers==4.44.2
# %pip install langchain==0.2.16
# %pip install langchain-community==0.2.16
# %pip install langchain-core==0.2.38
# %pip install langchain-huggingface==0.0.3
# %pip install langchain-text-splitters==0.2.4
# %pip install pypdf==5.0.1
# %pip install faiss-cpu==1.9.0
# %pip install pandas 
# %pip install openpyxl
# %pip install pymongo
# %pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %% [markdown]
# ## Classi

# %%
# Importazione delle classi dai file nella cartella classes
from DBManager import DBManager
from VectorStoreManager import VectorStoreManager
from LangchainManager import LangchainManager

# Inizializzazione del DatabaseManager
db_manager = DBManager(db_name='test', collection_name='test')

# Inizializzazione del VectorStoreManager
vector_store_manager = VectorStoreManager()

# Inizializzazione del LangchainManager
langchain_manager = LangchainManager(
    openai_api_base="https://047c-195-230-200-203.ngrok-free.app",
    api_key="EMPTY"
)
# Out:
# Connected to MongoDB
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
# Creazione della chain di Langchain
retriever = vector_store_manager.vector_store.as_retriever(k=1)  # Assicurati che il vector store sia inizializzato
qa_chain = langchain_manager.create_chain(retriever)

# %% [markdown]
# ## Definizione funzioni pymongo

# %%
from pymongo import MongoClient

# Connessione al server MongoDB
client = MongoClient('localhost', 27017)

# Selezione del database e della collection
db = client['test']
collection = db['test']

# %% [markdown]
# !!utilizzo delle function non ottimale: accedono ad un elemento "collection" che è esterno alla funzione

# %%
def inserisci_documento(documento):
    result = collection.insert_one(documento)
    return result.inserted_id
 


def leggi_documento(filtro):
    documento = collection.find_one(filtro)
    return documento



def aggiorna_documento(filtro, nuovi_dati):
    result = collection.update_one(filtro, {"$set": nuovi_dati})
    return result.modified_count
 


 
from langchain_community.document_loaders import PyPDFLoader
# Funzione per inserire un documento

def inserisci_documento_pypdf(documento_pypdf, numero):

    # Converti l'oggetto Document in un dizionario
    documento_dict = {
        "Num_chunk": numero , 
        "page_content": documento_pypdf.page_content,
        "metadata": documento_pypdf.metadata
    } 
    result = collection.insert_one(documento_dict)
    return result.inserted_id

# %% [markdown]
# ## Lettura di un pdf con un loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("./files_pdf/thinkpython2.pdf")
loaded_data = loader.load_and_split()
loaded_data
# Out:
# [Document(metadata={'source': './files_pdf/thinkpython2.pdf', 'page': 0}, page_content='Think Python\nHow to Think Like a Computer Scientist\n2nd Edition, Version 2.4.0'),
#  Document(metadata={'source': './files_pdf/thinkpython2.pdf', 'page': 2}, page_content='Think Python\nHow to Think Like a Computer Scientist\n2nd Edition, Version 2.4.0\nAllen Downey\nGreen Tea Press\nNeedham, Massachusetts'),
# ...

# %%
[i.replace(' ','') for i in loaded_data[50].page_content.split('\n')]
# Out:
# ['30Chapter4.Casestudy:interfacedesign',
#  'ThismeansthatbobreferstoanobjectwithtypeTurtleasdeﬁnedinmoduleturtle.',
#  'mainlooptellsthewindowtowaitfortheusertodosomething,althoughinthiscase',
#  'there’snotmuchfortheusertodoexceptclosethewindow.',
#  'OnceyoucreateaTurtle,youcancallamethodtomoveitaroundthewindow.Amethod',
#  'issimilartoafunction,butitusesslightlydifferentsyntax.Forexample,tomovetheturtle',
#  'forward:',
#  'bob.fd(100)',
#  'Themethod,fd,isassociatedwiththeturtleobjectwe’recallingbob.Callingamethodis',
#  'likemakingarequest:youareaskingbobtomoveforward.',
#  'Theargumentoffdisadistanceinpixels,sotheactualsizedependsonyourdisplay.',
#  'OthermethodsyoucancallonaTurtlearebktomovebackward,ltforleftturn,andrt',
#  'rightturn.Theargumentforltandrtisanangleindegrees.',
#  'Also,eachTurtleisholdingapen,whichiseitherdownorup;ifthepenisdown,theTurtle',
#  'leavesatrailwhenitmoves.Themethodspuandpdstandfor“penup”and“pendown”.',
# ...

# %% [markdown]
# ## Chunk processing

# %% [markdown]
# ### Split in chunk significativi

# %% [markdown]
# !! si poteva approfondire l'analisi dell'ingestion testando diversi chunk size, overlap ecc.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text=[loaded_data[i].page_content for i in range(24,26)]
text="".join(text)



# Dizionario di sostituzioni
replacements = {
    '\n\n\n': '\n\n',  # Normalizza i ritorni a capo multipli (ad esempio, da 3 a 2)
    '\n\n': '\n\n',    # Mantieni i doppi ritorni per separare i paragrafi
    '-\n': '',         # Unisci parole spezzate alla fine della riga (es. "Python-\nista" diventa "Pythonista")
    '\n ': '\n',       # Rimuovi spazi extra dopo i ritorni a capo
    ' \n': '',         # Rimuovi ritorni a capo tra parole che non sono separate correttamente
    '\n': ' ',         # Converti singoli ritorni a capo in spazi per mantenere la continuità del testo
}

# Replace each character in the dictionary
for old, new in replacements.items():
    text = text.replace(old, new)


# text splitter
text_splitter = RecursiveCharacterTextSplitter(

    chunk_size=600,
    chunk_overlap=50,
    length_function=len,
    # separators=[' '],
    is_separator_regex=False,
)

texts = text_splitter.create_documents([text])
texts
# Out:
# [Document(page_content="4 Chapter 1. The way of the program 1.5 Values and types Avalue is one of the basic things a program works with, like a letter or a number. Some values we have seen so far are 2,42.0 , and 'Hello, World! '. These values belong to different types :2is an integer ,42.0 is aﬂoating-point number , and 'Hello, World! 'is astring , so-called because the letters it contains are strung together. If you are not sure what type a value has, the interpreter can tell you: >>> type(2) <class 'int'> >>> type(42.0) <class 'float '> >>> type( 'Hello, World! ') <class 'str'> In these results, the word “class”"),
# ...

# %%
for i in texts:
    print(len(i.page_content))
# Out:
# 598
# 599
# 595
# 593
# 596
# 599
# 595
# 593
# 445

# %% [markdown]
# ### Salvataggio dei chunk in mongodb

# %% [markdown]
# !! non viene utilizzato il ritorno della funzione, si potrebbe stampare per avere dei log

# %%
'''
for i in range(len(texts)):
    inserisci_documento_pypdf(texts[i],i)
    
'''

# Salvataggio chunk in MongoDB
for i in range(len(texts)):
    db_manager.insert_document({
        "Num_chunk": i, 
        "page_content": texts[i].page_content,
        "metadata": texts[i].metadata
    })

# %% [markdown]
# ### Recupero dei chunk da mongodb

# %% [markdown]
# !! si poteva utilizzare la find senza query per ottenere tutti i documenti, oppure usare la list comprehension

# %%
'''
recupero_chunk=[]

for i in range(len(texts)):
    lettura=leggi_documento({"Num_chunk":i})
    recupero_chunk.append(lettura)
print(recupero_chunk)

'''

recupero_chunk = []

for i in range(len(texts)):
    lettura = db_manager.read_document({"Num_chunk": i})
    recupero_chunk.append(lettura)

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('6717b35127b3a45fcbdff3de'),
#   'nome': 'Mario Rossi',
#   'età': 31,
#   'città': 'Roma'},
#  {'_id': ObjectId('672255366ac98a65459dfcb7'),
#   'Num_chunk': 0,
#   'page_content': "4 Chapter 1. The way of the program 1.5 Values and types Avalue is one of the basic things a program works with, like a letter or a number. Some values we have seen so far are 2,42.0 , and 'Hello, World! '. These values belong to different types :2is an integer ,42.0 is aﬂoating-point number , and 'Hello, World! 'is astring , so-called because the letters it contains are strung together. If you are not sure what type a value has, the interpreter can tell you: >>> type(2) <class 'int'> >>> type(42.0) <class 'float '> >>> type( 'Hello, World! ') <class 'str'> In these results, the word “class”",
#   'metadata': {}},
#  {'_id': ObjectId('672255366ac98a65459dfcb8'),
#   'Num_chunk': 1,
# ...

# %%
#from langchain_community.document_loaders import Document
from langchain.schema import Document
document_list=[]

for i in range(len(texts)): 
    document_list.append(Document(page_content=recupero_chunk[i]["page_content"], metadata=recupero_chunk[i]["metadata"]))


# Verifica del contenuto del documento
print(document_list[0].page_content)
# Out:
# 4 Chapter 1. The way of the program 1.5 Values and types Avalue is one of the basic things a program works with, like a letter or a number. Some values we have seen so far are 2,42.0 , and 'Hello, World! '. These values belong to different types :2is an integer ,42.0 is aﬂoating-point number , and 'Hello, World! 'is astring , so-called because the letters it contains are strung together. If you are not sure what type a value has, the interpreter can tell you: >>> type(2) <class 'int'> >>> type(42.0) <class 'float '> >>> type( 'Hello, World! ') <class 'str'> In these results, the word “class”

# %%
print(len(document_list))
# Out:
# 9

# %% [markdown]
# ### Caricamento sul vector store (applicando embeddings)

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import FAISS

huggingface_embeddings = HuggingFaceBgeEmbeddings(
    model_name="BAAI/bge-small-en-v1.5",  # alternatively use "sentence-transformers/all-MiniLM-l6-v2" (faster)
    model_kwargs={'device':'cpu'}, #CPU run or 'device': 'cuda' for GPU use
    encode_kwargs={'normalize_embeddings': True} #Normalization is active, which means that the resulting vectors will have unit length. Normalization can be useful when you want to compare the similarity of sentences using methods like dot product or cosine similarity, as it makes the embeddings comparable on a common scale.
)


vector_db = FAISS.from_documents(document_list, huggingface_embeddings)

question = "what is parsing?"

response = vector_db.similarity_search_with_score(query=question)
response
# Out:
# [(Document(page_content='+and / are legal tokens, you can’t have one right after the other. Similarly, in a chemical formula the subscript comes after the element name, not before. This is @ well-structured Engli$h sentence with invalid t*kens in it. This sentence all valid tokens has, but invalid structure with. When you read a sentence in English or a statement in a formal language, you have to ﬁgure out the structure (although in a natural language you do this subconsciously). This process is called parsing . Although formal and natural languages have many features in common—tokens, structure, and syntax—there are'),
#   0.6470848),
# ...

# %% [markdown]
# ## Implementazione modello

# %%
from langchain_community.vectorstores import FAISS
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.chat_models import ChatOpenAI

retriever = vector_db.as_retriever(k=1)

template = """Answer the question based only on the following context:

{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
model = ChatOpenAI(
    openai_api_base="https://7af2-195-230-200-203.ngrok-free.app/v1",
    api_key="EMPTY"
)


def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

chain = (
    {"context": retriever | format_docs , "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
chain.invoke("which value types string,integers and floating point number belongs to according to python interpreter?")
# Out:
# "According to the given context, the value types and their corresponding categories (or classes) as per the Python interpreter are:\n\n1. string: belongs to class'str'\n2. integers: belongs to class 'int'\n3. floating-point number: belongs to class 'float'"

# %% [markdown]
# ### Creazione test set con domande e risposte attese

# %%
import pandas as pd 

q_a = pd.read_excel("./files_pdf/q_a.xlsx")
q_a
# Out:
#                                              Domanda  \
# 0                                    what is parsing
# 1  what is the definition of natural and formal l...
# 2  what are the features in common between natura...
# 3  what is the difference in terms of redundancy ...
# 4        are programming languages formal or natural
# 5  what is this number 1,000,000 according to pyt...
# 6  which type string,integers and floating point ...
#
#                                     Risposta attesa
# 0  When you read a sentence in English or a state...
# 1  Natural languages are the languages people spe...
# 2                        token, structure and syntax
# 3  natural languages employ lots of redundancy. A...
# 4  Programming languages are formal languages tha...
# 5  (1, 0, 0) a comma separated sequence of integers
# 6  integers belong to the type int, strings belon...

# %%
q_a.iloc[1,0]
q_a.shape[0]
# Out:
# 7

# %%
q_a.iloc[6,0]="which value types string,integers and floating point number belongs to according to python interpreter"
q_a.iloc[6,0]
# Out:
# 'which value types string,integers and floating point number belongs to according to python interpreter'

# %%
answers=[chain.invoke(q_a.iloc[i,0]) for i in range(q_a.shape[0])]
answers
# Out:
# ['When you read a sentence in English or a statement in a formal language, you have to figure out the structure (although in a natural language you do this subconsciously). This process is called parsing.',
#  'According to the given context, the definitions of natural and formal languages are:\n\n1. **Natural languages**: These are languages that people speak, such as English, Spanish, and French, which were not designed by people but evolved naturally. They are characterized by:\n   - Ambiguity\n   - Redundancy\n   - Literalness (often using idiom and metaphor)\n\n2. **Formal languages**: These are languages that are designed by people for specific applications, such as:\n   - Mathematics notation\n   - Chemical representation\n   - Programming languages\n   They are characterized by:\n   - Unambiguity\n   - Reduced redundancy\n   - Literalness (meaning exactly what they say)\n   - Strict syntax rules governing statement structure',
# ...

# %%
q_a["Risposta LLM"]= answers
q_a
# Out:
#                                              Domanda  \
# 0                                    what is parsing
# 1  what is the definition of natural and formal l...
# 2  what are the features in common between natura...
# 3  what is the difference in terms of redundancy ...
# 4        are programming languages formal or natural
# 5  what is this number 1,000,000 according to pyt...
# 6  which value types string,integers and floating...
#
#                                     Risposta attesa   \
# 0  When you read a sentence in English or a state...
# 1  Natural languages are the languages people spe...
# 2                        token, structure and syntax
# 3  natural languages employ lots of redundancy. A...
# 4  Programming languages are formal languages tha...
# 5  (1, 0, 0) a comma separated sequence of integers
# 6  integers belong to the type int, strings belon...
#
#                                         Risposta LLM
# 0  When you read a sentence in English or a state...
# ...

# %%
q_a.to_excel("results1.xlsx")

# %% [markdown]
# ### Test  RAG con un approccio a streaming

# %%
def stream_chain(chain,question):

    for s in chain.stream(question):
        print(s, end="", flush=True)

# %%
questions= [q_a.iloc[i,0] for i in range(q_a.shape[0])]
for question in questions:
    stream_chain(chain, question)
# Out:
# Parsing is the process of figuring out the structure of a sentence or a statement in a language, whether it's a natural language like English or a formal language like a programming language. This process allows you to understand the meaning behind the words or symbols and how they relate to each other.According to the context, the definitions of natural and formal languages are:
#
# 1. **Natural Languages**:
#    - Characterized by ambiguity
#    - Employ redundancy to make up for ambiguity
#    - Contain literalness (idiom, metaphor)
#    - Designed to be more verbose
#    - Evolved naturally
#
#    Example: English, Spanish, French
#
# 2. **Formal Languages**:
#    - Designed to be nearly or completely unambiguous
#    - Less redundant and more concise
#    - Mean exactly what they say (no literalness)
#    - Governed by strict syntax rules
#    - Designed by people for specific applications
#
# ...

# %% [markdown]
# ## Trasformazione rag in un chatbot con history

# %%
 
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain_community.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain

from operator import itemgetter
from langchain_core.runnables import RunnableLambda, RunnablePassthrough, RunnableParallel


llm = ChatOpenAI(
    openai_api_base="https://7af2-195-230-200-203.ngrok-free.app/v1",
    api_key="EMPTY"
)


memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

template = ("""Answer the question based only on the following context:

{context}

Question: {question}
""") 


prompt = ChatPromptTemplate.from_template(template)

retriever = vector_db.as_retriever( search_kwargs={"k": 1} )
output_parser = StrOutputParser()

def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])


#chain
qa_chain = (
            RunnableParallel({
                "context": itemgetter("question") | retriever | format_docs,  
                "question": itemgetter("question")
            })
            | {
                "question": itemgetter("question"),
                "output": prompt | llm | output_parser,
                "context": itemgetter("context"), 

            }
    )

# %%
qa_chain.invoke({"question": "what is parsing?"})
# Out:
# {'question': 'what is parsing?',
#  'output': "Parsing is the process of figuring out the structure of a sentence or statement in a language, whether it's natural or formal.",
#  'context': '+and / are legal tokens, you can’t have one right after the other. Similarly, in a chemical formula the subscript comes after the element name, not before. This is @ well-structured Engli$h sentence with invalid t*kens in it. This sentence all valid tokens has, but invalid structure with. When you read a sentence in English or a statement in a formal language, you have to ﬁgure out the structure (although in a natural language you do this subconsciously). This process is called parsing . Although formal and natural languages have many features in common—tokens, structure, and syntax—there are'}

# %% [markdown]
# ### Chatbot con history

# %%
from langchain_core.messages import BaseMessage, AIMessage
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.chat_history import BaseChatMessageHistory
from typing import List

class InMemoryHistory(BaseChatMessageHistory, BaseModel):
    """In memory implementation of chat message history."""

    messages: List[BaseMessage] = Field(default_factory=list)
    

    def add_messages(self, messages: List[BaseMessage]) -> None:
        """Add a list of messages to the store"""
        self.messages.extend(messages)
        
    def clear(self) -> None:
        self.messages = []

# Here we use a global variable to store the chat message history.
# This will make it easier to inspect it to see the underlying results.
store = {}

def get_by_session_id(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = InMemoryHistory()
    return store[session_id]

# %%
from langchain_core.runnables.history import RunnableWithMessageHistory
chain_with_history = RunnableWithMessageHistory(qa_chain,get_by_session_id, input_messages_key="question",history_messages_key="history")

# %%
chain_with_history.invoke({"question": "hello"}, config={"configurable": {"session_id": "1"}})
# Out:
# {'question': 'hello',
#  'output': 'I don\'t have enough information to answer your question. The provided context only includes a passage about values and types in a programming context, and ends with a code snippet. There is no mention of the word "hello" in the context provided.',
#  'context': "4 Chapter 1. The way of the program 1.5 Values and types Avalue is one of the basic things a program works with, like a letter or a number. Some values we have seen so far are 2,42.0 , and 'Hello, World! '. These values belong to different types :2is an integer ,42.0 is aﬂoating-point number , and 'Hello, World! 'is astring , so-called because the letters it contains are strung together. If you are not sure what type a value has, the interpreter can tell you: >>> type(2) <class 'int'> >>> type(42.0) <class 'float '> >>> type( 'Hello, World! ') <class 'str'> In these results, the word “class”"}

# %%
chain_with_history.invoke({"question": "what is parsing?"}, config={"configurable": {"session_id": "1"}})
# Out:
# {'question': 'what is parsing?',
#  'output': 'Parsing is the process of figuring out the structure of a sentence or statement in a formal language, although in a natural language, this is typically done subconsciously.',
#  'context': '+and / are legal tokens, you can’t have one right after the other. Similarly, in a chemical formula the subscript comes after the element name, not before. This is @ well-structured Engli$h sentence with invalid t*kens in it. This sentence all valid tokens has, but invalid structure with. When you read a sentence in English or a statement in a formal language, you have to ﬁgure out the structure (although in a natural language you do this subconsciously). This process is called parsing . Although formal and natural languages have many features in common—tokens, structure, and syntax—there are'}

# %%
chain_with_history.invoke({"question": "which value types string,integers and floating point number belongs to according to python interpreter"}, config={"configurable": {"session_id": "1"}})
# Out:
# {'question': 'which value types string,integers and floating point number belongs to according to python interpreter',
#  'output': 'According to the Python interpreter, the value types are as follows:\n\n1. String: str\n2. Integers: int\n3. Floating point numbers: float',
#  'context': "4 Chapter 1. The way of the program 1.5 Values and types Avalue is one of the basic things a program works with, like a letter or a number. Some values we have seen so far are 2,42.0 , and 'Hello, World! '. These values belong to different types :2is an integer ,42.0 is aﬂoating-point number , and 'Hello, World! 'is astring , so-called because the letters it contains are strung together. If you are not sure what type a value has, the interpreter can tell you: >>> type(2) <class 'int'> >>> type(42.0) <class 'float '> >>> type( 'Hello, World! ') <class 'str'> In these results, the word “class”"}

# %%
get_by_session_id("1")
# Out:
# InMemoryHistory(messages=[HumanMessage(content='hello'), AIMessage(content='I don\'t have enough information to answer your question. The provided context only includes a passage about values and types in a programming context, and ends with a code snippet. There is no mention of the word "hello" in the context provided.'), HumanMessage(content='what is parsing?'), AIMessage(content='Parsing is the process of figuring out the structure of a sentence or statement in a formal language, although in a natural language, this is typically done subconsciously.'), HumanMessage(content='which value types string,integers and floating point number belongs to according to python interpreter'), AIMessage(content='According to the Python interpreter, the value types are as follows:\n\n1. String: str\n2. Integers: int\n3. Floating point numbers: float')])

# %% [markdown]
# ### Esecuzione del test set e salvataggio su mongodb

# %% [markdown]
# !! è stato utilizzato sempre lo stesso session id, si potevano simulare più conversazioni in parallelo usando diversi session_id

# %%
for i in range(q_a.shape[0]):
    answer=chain_with_history.invoke({"question": q_a.iloc[i,0]} , config={"configurable": {"session_id": "1"}})
    inserisci_documento(answer)

# %% [markdown]
# ### Test streaming

# %%
from langchain.callbacks.base import BaseCallbackHandler

class CallbackHandler(BaseCallbackHandler):
    def on_llm_new_token(self, token: str, **kwargs) -> None:
        """Gestisci ogni nuovo token ricevuto dallo streaming."""
        print(token, end="", flush=True)  
    


llm = ChatOpenAI(
    openai_api_base="https://7af2-195-230-200-203.ngrok-free.app/v1",
    api_key="EMPTY",
    streaming=True,
    callbacks=[CallbackHandler()]
)
qa_chain = (
            RunnableParallel({
                "context": itemgetter("question") | retriever | format_docs,  
                "question": itemgetter("question")
            })
            | {
                "question": itemgetter("question"),
                "output": prompt | llm | output_parser,
                "context": itemgetter("context"), 

            }
    )

chain_with_history = RunnableWithMessageHistory(qa_chain,get_by_session_id, input_messages_key="question",history_messages_key="history")

# %%
def stream_response(session_id, question,chain):
    result = chain.invoke({"question": question} , config={"configurable": {"session_id": session_id}})
    return result

# %%
stream_response(session_id="1", chain=chain_with_history,question="what is parsing")
# Out:
# Parsing is the process of figuring out the structure of a sentence or a statement in a language, whether it's natural or formal.
# {'question': 'what is parsing',
#  'output': "Parsing is the process of figuring out the structure of a sentence or a statement in a language, whether it's natural or formal.",
#  'context': '+and / are legal tokens, you can’t have one right after the other. Similarly, in a chemical formula the subscript comes after the element name, not before. This is @ well-structured Engli$h sentence with invalid t*kens in it. This sentence all valid tokens has, but invalid structure with. When you read a sentence in English or a statement in a formal language, you have to ﬁgure out the structure (although in a natural language you do this subconsciously). This process is called parsing . Although formal and natural languages have many features in common—tokens, structure, and syntax—there are'}

# %%
questions= [q_a.iloc[i,0] for i in range(q_a.shape[0])]
for question in questions:
    stream_response(session_id="1", chain=chain_with_history,question=question)
# Out:
# Parsing is the process of figuring out the structure of a sentence or a statement in a formal or natural language.Based on the given context, here are the definitions of natural and formal languages:
#
# 1. **Natural Language**: A language that is used to communicate by people in everyday life, often full of ambiguity, redundancy, and literalness. It deals with contextual clues and other information to resolve meaning.
#
# ...

# %% [markdown]
# !! manca salvataggio delle conversazioni del chatbot su mongodb
